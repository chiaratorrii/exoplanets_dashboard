# %% [markdown]
# # Exoplanets data retrieval test

# %% [markdown]
# ### Nasa API data extraction

# %%
import requests
import pandas as pd
from io import StringIO
from urllib.parse import quote_plus

# %%
# Function to download and save data from the NASA Exoplanet Archive
def fetch_exoplanet_tap(sql, fmt="csv", save_path=None):
    """
    Downloads data from the NASA Exoplanet Archive via TAP, loads it into a DataFrame,
    and (optionally) saves the CSV file.

    Parameters:
        sql (str): SQL query to execute.
        fmt (str): Output format (default: "csv").
        save_path (str): File path to save the CSV (optional).

    Returns:
        pd.DataFrame: The imported data.
    """
    url = f"https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query={quote_plus(sql)}&format={fmt}"
    print(f"Fetching data from: {url}")

    r = requests.get(url, timeout=60)
    r.raise_for_status()

    if save_path:
        with open(save_path, "w", encoding="utf-8") as f:
            f.write(r.text)
        print(f"✅ File saved as: {save_path}")

    df = pd.read_csv(StringIO(r.text))
    return df

# %%
try:
    sql = "select pl_name,hostname,sy_snum,sy_pnum,sy_mnum,discoverymethod,disc_year,disc_facility,disc_instrument,pl_orbper,pl_rade,pl_radj,pl_masse,pl_massj,pl_dens,st_rad,st_mass,sy_dist,releasedate from ps"
    df = fetch_exoplanet_tap(sql, save_path="exoplanet_data.csv")
    display(df.head())
except Exception as e:
    print("TAP failed:", e)
# Out:
# Fetching data from: https://exoplanetarchive.ipac.caltech.edu/TAP/sync?query=select+pl_name%2Chostname%2Csy_snum%2Csy_pnum%2Csy_mnum%2Cdiscoverymethod%2Cdisc_year%2Cdisc_facility%2Cdisc_instrument%2Cpl_orbper%2Cpl_rade%2Cpl_radj%2Cpl_masse%2Cpl_massj%2Cpl_dens%2Cst_rad%2Cst_mass%2Csy_dist%2Creleasedate+from+ps&format=csv
# ✅ File saved as: exoplanet_data.csv
#       pl_name  hostname  sy_snum  sy_pnum  sy_mnum discoverymethod  disc_year  \
# 0  Kepler-6 b  Kepler-6        1        1        0         Transit       2009
# 1  Kepler-6 b  Kepler-6        1        1        0         Transit       2009
# 2  Kepler-6 b  Kepler-6        1        1        0         Transit       2009
# 3  Kepler-6 b  Kepler-6        1        1        0         Transit       2009
# 4  Kepler-6 b  Kepler-6        1        1        0         Transit       2009
#
#   disc_facility   disc_instrument  pl_orbper    pl_rade   pl_radj   pl_masse  \
# 0        Kepler  Kepler CCD Array   3.234699  13.410000  1.196362        NaN
# 1        Kepler  Kepler CCD Array   3.234694  13.316002  1.187976        NaN
# 2        Kepler  Kepler CCD Array   3.234723  14.830000  1.323000  212.61900
# 3        Kepler  Kepler CCD Array   3.234699  13.103321  1.169000  205.63601
# 4        Kepler  Kepler CCD Array   3.234699        NaN       NaN        NaN
#
#    pl_massj  pl_dens   st_rad  st_mass  sy_dist releasedate
# 0       NaN      NaN  1.29100    1.047  587.039  2015-08-25
# 1       NaN      NaN  1.31474      NaN  587.039  2024-09-16
# 2     0.669    0.352  1.39100    1.209  587.039  2014-05-14
# 3     0.647    0.490  1.26100    1.114  587.039  2019-03-21
# 4       NaN      NaN  1.31474    0.990  587.039  2016-07-28

# %%
exoplanets=pd.read_csv("..\data\exoplanets_data.csv")

# %%
len(exoplanets.pl_name.unique())
# Out:
# 6042

# %%
unique_exo=exoplanets.sort_values(['pl_name', 'releasedate'], ascending=[True, False]).drop_duplicates(subset='pl_name', keep='first')

# %%
unique_exo.disc_facility.unique()
# Out:
# array(['Xinglong Station', 'Thueringer Landessternwarte Tautenburg',
#        'Okayama Astrophysical Observatory', 'W. M. Keck Observatory',
#        'Multiple Observatories', 'Lick Observatory', 'Gemini Observatory',
#        'Subaru Telescope', 'Paranal Observatory',
#        'Cerro Tololo Inter-American Observatory', 'Mauna Kea Observatory',
#        'European Space Agency (ESA) Gaia Satellite',
#        'Hubble Space Telescope', 'Kepler', 'Haute-Provence Observatory',
#        'McDonald Observatory', 'Anglo-Australian Telescope',
#        'Bohyunsan Optical Astronomical Observatory',
#        'Transiting Exoplanet Survey Satellite (TESS)',
#        'Roque de los Muchachos Observatory', 'K2',
#        'Wide-field Infrared Survey Explorer (WISE) Satellite Mission',
#        'La Silla Observatory', 'Calar Alto Observatory',
#        'NASA Infrared Telescope Facility (IRTF)', 'CoRoT',
#        'Multiple Facilities', 'Yunnan Astronomical Observatory',
#        'Spitzer Space Telescope', 'MEarth Project',
#        'Very Long Baseline Array', 'Acton Sky Portal Observatory',
#        'Palomar Observatory', 'HATNet', 'HATSouth',
#        'Kitt Peak National Observatory', 'Las Campanas Observatory',
#        'CHaracterising ExOPlanets Satellite (CHEOPS)',
#        'European Southern Observatory',
#        'Fred Lawrence Whipple Observatory', 'Apache Point Observatory',
#        'Atacama Large Millimeter Array (ALMA)', 'KELT', 'KELT-South',
#        'KELT-North', 'KMTNet', 'KOINet', 'SPECULOOS Southern Observatory',
#        'Large Binocular Telescope Observatory',
#        'South African Radio Astronomy Observatory (SARAO)', 'MOA',
#        'Next-Generation Transit Survey (NGTS)', 'Winer Observatory',
#        'OGLE', 'Arecibo Observatory', 'Parkes Observatory', 'Qatar',
#        'Leoncito Astronomical Complex', 'Infrared Survey Facility',
#        'TrES', 'Teide Observatory', 'SuperWASP', 'SuperWASP-South',
#        'SuperWASP-North', 'WASP-South',
#        'James Webb Space Telescope (JWST)',
#        'United Kingdom Infrared Telescope', 'Haleakala Observatory', 'XO',
#        'Lowell Observatory', 'Zwicky Transient Facility',
#        'University of Canterbury Mt John Observatory'], dtype=object)

# %%
obs_position=pd.read_excel("..\data\eso-astronomical-observatory-sites.xlsx")

# %%
obs_position
# Out:
#                                                   Name Instruments  Altitude  \
# 0                      Ice Cube Neutrino N Observatory         NaN   -2452.0
# 1             Córdoba Astronomical Observatory Córdoba         NaN     434.0
# 2           La Plata Astronomical Observatory La Plata         NaN      17.0
# 3                 Vienna University Observatory Vienna         NaN     241.0
# 4                    Metsähovi Observatory Kirkkonummi         NaN      60.0
# ..                                                 ...         ...       ...
# 534              Chabot Space & Science Center Oakland         NaN     476.0
# 535  Naval Rsch. Lab. Radio Astronomical Observator...       Radio      30.0
# 536                        Bradley Observatory Decatur         NaN     316.0
# 537  Black Moshannon Observatory State College/Ratt...         NaN     738.0
# 538                  Pine Bluff Observatory Pine Bluff         NaN     366.0
#
#                                 Type  \
# 0    Modern Astronomical Observatory
# 1    Modern Astronomical Observatory
# 2    Modern Astronomical Observatory
# 3    Modern Astronomical Observatory
# 4    Modern Astronomical Observatory
# ..                               ...
# 534  Modern Astronomical Observatory
# 535  Modern Astronomical Observatory
# 536  Modern Astronomical Observatory
# 537  Modern Astronomical Observatory
# 538  Modern Astronomical Observatory
#
#                                     Description source  \
# 0    Modern Astronomical Observatory [-2452 meters ...
# 1    Modern Astronomical Observatory [434 meters AMSL]
# 2     Modern Astronomical Observatory [17 meters AMSL]
# 3    Modern Astronomical Observatory [241 meters AMSL]
# 4     Modern Astronomical Observatory [60 meters AMSL]
# ..                                                 ...
# 534  Modern Astronomical Observatory [476 meters AMSL]
# 535   Modern Astronomical Observatory [30 meters AMSL]
# 536  Modern Astronomical Observatory [316 meters AMSL]
# 537  Modern Astronomical Observatory [738 meters AMSL]
# 538  Modern Astronomical Observatory [366 meters AMSL]
#
#                                               Geometry  \
# 0           {"coordinates":[0.0,-90.0],"type":"Point"}
# 1    {"coordinates":[-64.1966666666667,-31.42166666...
# 2    {"coordinates":[-57.9316666666667,-34.90833333...
# 3    {"coordinates":[16.3366666666667,48.2316666666...
# 4    {"coordinates":[24.3966666666667,60.22],"type"...
# ..                                                 ...
# 534  {"coordinates":[-122.181666666667,37.818333333...
# 535  {"coordinates":[-77.0266666666667,38.821666666...
# 536  {"coordinates":[-84.2933333333333,33.765],"typ...
# 537  {"coordinates":[-78.005,40.9216666666667],"typ...
# 538  {"coordinates":[-89.685,43.0783333333333],"typ...
#
#                              geo_point_2d
# 0                              -90.0, 0.0
# 1    -31.4216666666667, -64.1966666666667
# 2    -34.9083333333333, -57.9316666666667
# 3      48.2316666666667, 16.3366666666667
# 4                 60.22, 24.3966666666667
# ..                                    ...
# 534   37.8183333333333, -122.181666666667
# 535   38.8216666666667, -77.0266666666667
# 536             33.765, -84.2933333333333
# 537             40.9216666666667, -78.005
# 538             43.0783333333333, -89.685
#
# [539 rows x 7 columns]

# %%
pd.merge(unique_exo, obs_position, how='left', left_on='disc_facility', right_on='Name')
# Out:
#          pl_name  hostname  sy_snum  sy_pnum  sy_mnum  discoverymethod  \
# 0       11 Com b    11 Com        2        1        0  Radial Velocity
# 1       11 UMi b    11 UMi        1        1        0  Radial Velocity
# 2       14 And b    14 And        1        1        0  Radial Velocity
# 3       14 Her b    14 Her        1        2        0  Radial Velocity
# 4     16 Cyg B b  16 Cyg B        3        1        0  Radial Velocity
# ...          ...       ...      ...      ...      ...              ...
# 6037   ups And b   ups And        2        3        0  Radial Velocity
# 6038   ups And c   ups And        2        3        0  Radial Velocity
# 6039   ups And d   ups And        2        3        0  Radial Velocity
# 6040   ups Leo b   ups Leo        1        1        0  Radial Velocity
# 6041    xi Aql b    xi Aql        1        1        0  Radial Velocity
#
#       disc_year                           disc_facility  \
# 0          2007                        Xinglong Station
# 1          2009  Thueringer Landessternwarte Tautenburg
# 2          2008       Okayama Astrophysical Observatory
# 3          2002                  W. M. Keck Observatory
# 4          1996                  Multiple Observatories
# ...         ...                                     ...
# 6037       1996                        Lick Observatory
# 6038       1999                  Multiple Observatories
# 6039       1999                  Multiple Observatories
# 6040       2021       Okayama Astrophysical Observatory
# 6041       2007       Okayama Astrophysical Observatory
#
#                     disc_instrument    pl_orbper  ...   st_mass   sy_dist  \
# 0        Coude Echelle Spectrograph   323.210000  ...  2.090000   93.1846
# 1        Coude Echelle Spectrograph   516.219970  ...  2.780000  125.3210
# 2        HIDES Echelle Spectrograph   186.760000  ...  1.780000   75.4392
# 3                HIRES Spectrometer  1765.038900  ...  0.910000   17.9323
# 4              Multiple Instruments   799.450000  ...  0.982996   21.1397
# ...                             ...          ...  ...       ...       ...
# 6037  Hamilton Echelle Spectrograph     4.617122  ...  1.294197   13.4054
# 6038           Multiple Instruments   241.223000  ...  1.294197   13.4054
# 6039           Multiple Instruments  1282.410000  ...  1.294197   13.4054
# 6040     HIDES Echelle Spectrograph   385.200000  ...  1.480000   52.5973
# 6041     HIDES Echelle Spectrograph   136.970000  ...  1.740000   56.1858
#
#       releasedate  Name  Instruments  Altitude  Type  Description source  \
# 0      2023-09-19   NaN          NaN       NaN   NaN                 NaN
# 1      2018-09-06   NaN          NaN       NaN   NaN                 NaN
# 2      2023-09-19   NaN          NaN       NaN   NaN                 NaN
# 3      2023-06-12   NaN          NaN       NaN   NaN                 NaN
# 4      2021-09-20   NaN          NaN       NaN   NaN                 NaN
# ...           ...   ...          ...       ...   ...                 ...
# 6037   2022-05-09   NaN          NaN       NaN   NaN                 NaN
# 6038   2021-09-20   NaN          NaN       NaN   NaN                 NaN
# 6039   2021-09-20   NaN          NaN       NaN   NaN                 NaN
# 6040   2022-01-10   NaN          NaN       NaN   NaN                 NaN
# 6041   2023-09-19   NaN          NaN       NaN   NaN                 NaN
#
#      Geometry geo_point_2d
# 0         NaN          NaN
# 1         NaN          NaN
# 2         NaN          NaN
# 3         NaN          NaN
# 4         NaN          NaN
# ...       ...          ...
# 6037      NaN          NaN
# 6038      NaN          NaN
# 6039      NaN          NaN
# 6040      NaN          NaN
# 6041      NaN          NaN
#
# [6042 rows x 26 columns]

# %%
exo_rad=10.95 * 2
bubble_plot_df = pd.DataFrame({
    'planet': ['earth', 'jupiter', 'exo'], 
    'rad': [1, 10.95, exo_rad],
    'y':[1, 1, 1]
})

# Dynamically calculate x positions
x_positions = [0]  # Start the first circle at x=0
for i in range(1, len(bubble_plot_df)):
    # Distance between perimeters is equal to the sum of radii of consecutive circles
    distance_between_centers = (bubble_plot_df["rad"][i - 1] + 2 + bubble_plot_df["rad"][i])/2
    x_positions.append(x_positions[-1] + distance_between_centers)

# Add x positions to the DataFrame
bubble_plot_df["x"] = x_positions

# %%
bubble_plot_df
# Out:
#     planet    rad  y       x
# 0    earth   1.00  1   0.000
# 1  jupiter  10.95  1   6.975
# 2      exo  21.90  1  24.400
