# %% [markdown]
# # Observatories geolocation

# %%
import pandas as pd

# %% [markdown]
# ## Scrape list of astronomical observatories from Wikipedia

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup

url = "https://en.wikipedia.org/wiki/List_of_astronomical_observatories"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/58.0.3029.110 Safari/537.36"
}

response = requests.get(url, headers=headers)
response.raise_for_status()

soup = BeautifulSoup(response.text, 'html.parser')

# Find the correct table by matching the headers
table = None
for tbl in soup.find_all('table', {'class':'wikitable'}):
    headers = [th.get_text(strip=True) for th in tbl.find_all('th')]
    if headers[:3] == ['Name', 'Established', 'Location']:
        table = tbl
        break

# Parse rows
rows = []
for tr in table.find_all('tr')[1:]:
    tds = tr.find_all('td')
    if len(tds) >= 3:
        name_td = tds[0]
        name_link = None
        a_tag = name_td.find('a', href=True)
        if a_tag:
            name_link = 'https://en.wikipedia.org' + a_tag['href']
        name_text = name_td.get_text(strip=True)
        established = tds[1].get_text(strip=True)
        location = tds[2].get_text(strip=True)
        rows.append({
            'Name': name_text,
            'Link': name_link,
            'Established': established,
            'Location': location
        })

observatories_df = pd.DataFrame(rows)

observatories_df.to_csv("../data/astronomical_observatories_with_links.csv", index=False)

# %% [markdown]
# ## Geolocation

# %% [markdown]
# ### Add coordinates using geopy Nominatim and Openstreetmap

# %%
from geopy.geocoders import Nominatim
from geopy.extra.rate_limiter import RateLimiter
import logging

logging.basicConfig(level=logging.INFO)

geolocator = Nominatim(
    user_agent="your-app-name/1.0 (chiara.torri@yahoo.com)",  # required by policy
    timeout=5
)

# Respect rate limits (e.g. 1 request per second)
geocode = RateLimiter(geolocator.geocode, min_delay_seconds=1)

def get_location(city_name: str):
    # First, try the full string
    try:
        location = geocode(city_name)
        if location:
            return (location.latitude, location.longitude)
    except Exception as e:
        logging.warning("Error geocoding %r (full): %s", city_name, e)

    # Fallback: first two comma-separated parts (as string)
    parts = [p.strip() for p in city_name.split(",") if p.strip()]
    if len(parts) >= 2:
        try:
            q = ", ".join(parts[:2])
            location = geocode(q)
            if location:
                return (location.latitude, location.longitude)
        except Exception as e:
            logging.warning("Error geocoding %r (first two parts): %s", city_name, e)

    # Fallback: just the first part (often city)
    if parts:
        try:
            q = parts[0]
            location = geocode(q)
            if location:
                return (location.latitude, location.longitude)
        except Exception as e:
            logging.warning("Error geocoding %r (first part): %s", city_name, e)

    logging.warning("⚠️ no coordinates found for: %r", city_name)
    return (None, None)

# %%
observatories_location=pd.DataFrame({'Location': list(observatories_df['Location'].unique())})
observatories_location['geolocation'] = observatories_location['Location'].apply(get_location)
# Out:
# WARNING:root:⚠️ no coordinates found for: 'Sun-Earth L1'
# WARNING:root:⚠️ no coordinates found for: 'In theMediterranean SeanearToulon, France'
# WARNING:root:⚠️ no coordinates found for: 'Highly eccentric Earth orbit'
# WARNING:root:⚠️ no coordinates found for: 'Llano de Chajnantor Observatory, Chile'
# WARNING:root:⚠️ no coordinates found for: 'Low Earth orbit'
# WARNING:root:⚠️ no coordinates found for: 'Earth–SunL1 point'
# WARNING:root:⚠️ no coordinates found for: 'Highly eccentricEarth orbit'
# WARNING:root:⚠️ no coordinates found for: 'Polar orbit'
# WARNING:root:⚠️ no coordinates found for: 'Nauchnyi, Crimea'
# WARNING:root:⚠️ no coordinates found for: '500\xa0kmLEO'
# WARNING:root:⚠️ no coordinates found for: 'Mount Entoto, Ethiopia'
# WARNING:root:⚠️ no coordinates found for: 'Earth–SunL2Lagrangian point'
# WARNING:root:⚠️ no coordinates found for: 'Southern Operations Center:La Serena, Chile; Northern Operations Center:Hilo, Hawaii, US'
# WARNING:root:⚠️ no coordinates found for: 'Elliptical Earth-centered orbit'
# WARNING:root:⚠️ no coordinates found for: '550\xa0kmLEO'
# WARNING:root:⚠️ no coordinates found for: 'Earth–Sun L2 point'
# WARNING:root:⚠️ no coordinates found for: 'Earth orbit'
# WARNING:root:⚠️ no coordinates found for: 'Mount Gargash, Iran'
# WARNING:root:⚠️ no coordinates found for: 'Earth-trailingheliocentric orbit'
# WARNING:root:⚠️ no coordinates found for: 'Mount Kyllini, Greece'
# WARNING:root:⚠️ no coordinates found for: '14\xa0km in thestratosphere'
# WARNING:root:⚠️ no coordinates found for: 'Mount Lulin, Taiwan'
# WARNING:root:⚠️ no coordinates found for: 'Luoxue Mountain,YunnanProvince, China'
# WARNING:root:⚠️ no coordinates found for: 'Headquarters:Toulouse, FrancePyrenees, FranceToulouse, France'
# WARNING:root:⚠️ no coordinates found for: 'Gorce Mountains, Poland'
# WARNING:root:⚠️ no coordinates found for: 'Headquarters:Mitaka, Tokyo, Japan'
# WARNING:root:⚠️ no coordinates found for: 'Jyväskylän maalaiskunta, Western Finland Province, Finland'
# WARNING:root:⚠️ no coordinates found for: 'Pian dei Termini(nearSan Marcello Pistoiese), Italy'
# WARNING:root:⚠️ no coordinates found for: 'Piwnicenear Toruń, Poland'
# WARNING:root:⚠️ no coordinates found for: 'Pulkovskiye Heights, Russia'
# WARNING:root:⚠️ no coordinates found for: 'Earth-Moon L2'
# WARNING:root:⚠️ no coordinates found for: 'Lunar orbit'
# WARNING:root:⚠️ no coordinates found for: 'PeakRozhen, Bulgaria'
# WARNING:root:⚠️ no coordinates found for: 'Low Earth orbit; re-entered in 1979'
# WARNING:root:⚠️ no coordinates found for: '709\xa0kmSSO; life: 3 years'
# WARNING:root:⚠️ no coordinates found for: 'Sun-synchronousEarth orbit'
# WARNING:root:⚠️ no coordinates found for: 'Heliocentric orbit'
# WARNING:root:⚠️ no coordinates found for: '14\xa0km in Earthstratosphere'
# WARNING:root:⚠️ no coordinates found for: 'Headquarters:Castel Gandolfo, ItalyMount Graham, Arizona, US'
# WARNING:root:⚠️ no coordinates found for: 'Various locations on Earth'
# WARNING:root:⚠️ no coordinates found for: 'YangbajingValley,Tibet, China'

# %%
observatories_location['type']=['earth' if observatories_location.geolocation[i]!='(None, None)' else pd.NA for i in range(len(observatories_location))]
observatories_location.to_csv("../data/observatories_location_geocoded.csv", index=False)

# %% [markdown]
# ### Add missing locations

# %%
observatories_df=pd.read_csv("../data/astronomical_observatories_with_links.csv")
observatories_location=pd.read_csv("../data/observatories_location_geocoded.csv")
observatories_df = observatories_df.merge(observatories_location, on='Location', how='left')

# %%
observatories_df['type']=['space' if (observatories_df.geolocation[i]=="(None, None)") & ('orbit' in observatories_df.Location[i]) else observatories_df.type[i] for i in range(len(observatories_df))]
observatories_df['type']=['space' if (observatories_df.geolocation[i]=="(None, None)") & ('Sun' in observatories_df.Location[i]) else observatories_df.type[i] for i in range(len(observatories_df))]

# %%
observatories_df[(observatories_df.geolocation=="(None, None)") & (observatories_df.type.isna())].to_excel('../data/observatories_no_location_type.xlsx', index=False)

# %%
filter_missing=((observatories_df.geolocation=="(None, None)") & (observatories_df.type.isna()))
observatories_df=observatories_df[~filter_missing]
observatories_df['note']=pd.NA

# %%
observatories_no_location_type=pd.read_excel('../data/observatories_no_location_type.xlsx')

observatories_df_final=pd.concat([observatories_df, observatories_no_location_type], ignore_index=True)
observatories_df_final.to_csv("../data/astronomical_observatories_final.csv", index=False)

# %% [markdown]
# ## Merge with exoplanet data

# %%
exoplanets=pd.read_csv("../data/exoplanets_data.csv")
unique_exo = exoplanets.sort_values(['pl_name', 'releasedate'], ascending=[True, False]).drop_duplicates(subset='pl_name', keep='first')

# %%
count_by_observatory=pd.DataFrame(unique_exo.groupby('disc_facility')['pl_name'].count()).reset_index()

# %%
count_by_observatory
# Out:
#                             disc_facility  pl_name
# 0            Acton Sky Portal Observatory        2
# 1              Anglo-Australian Telescope       35
# 2                Apache Point Observatory        2
# 3                     Arecibo Observatory        3
# 4   Atacama Large Millimeter Array (ALMA)        1
# ..                                    ...      ...
# 67                      Winer Observatory        1
# 68                                     XO        6
# 69                       Xinglong Station        2
# 70        Yunnan Astronomical Observatory        3
# 71              Zwicky Transient Facility        2
#
# [72 rows x 2 columns]

# %%
observatories_df_final=pd.read_csv("../data/astronomical_observatories_final.csv")

# %%
observatories_df_final.fillna('Unknown', inplace=True)
# Out:
# C:\Users\kiara\AppData\Local\Temp\ipykernel_27208\1540478123.py:1: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value 'Unknown' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   observatories_df_final.fillna('Unknown', inplace=True)

# %%
count_by_observatory_with_location=pd.merge(count_by_observatory, observatories_df_final, left_on='disc_facility', right_on='Name', how='left')

# %%
missing_location=count_by_observatory_with_location[count_by_observatory_with_location.geolocation.isna()]

# %%
# missing_location.to_excel('../data/observatories_missing_location_in_exoplanet_data.xlsx', index=False)

# %%
len(missing_location)
# Out:
# 46

# %%
len(count_by_observatory_with_location)
# Out:
# 72

# %%
len(count_by_observatory_with_location[~count_by_observatory_with_location.geolocation.isna()])
# Out:
# 26

# %%
count_by_observatory_with_location_full=count_by_observatory_with_location[~count_by_observatory_with_location.geolocation.isna()]

# %%
missing_location=pd.read_excel('../data/observatories_missing_location_in_exoplanet_data.xlsx')

# %%
observatories_exo_geolocated=pd.concat([count_by_observatory_with_location_full, missing_location], ignore_index=True)

# %%
observatories_exo_geolocated.to_csv("../data/observatories_exoplanets_geolocated.csv", index=False)

# %%
df=pd.read_csv('../data/observatories_exoplanets_geolocated.csv')

# %%
df['geolocation']
# Out:
# 0       (32.7892103, -105.81857)
# 1      (18.4047499, -66.6810353)
# 2       (36.8414197, -2.4628135)
# 3     (-24.5563029, -69.4226479)
# 4      (31.6890556, -110.884703)
#                  ...
# 71           (-32.3783, 20.8105)
# 72                           NaN
# 73          (19.8256, -155.4761)
# 74     (40.4659616, 117.7921122)
# 75        (33.35731, -116.85981)
# Name: geolocation, Length: 76, dtype: object

# %%
df.fillna('Unknown', inplace=True)

# %%
df
# Out:
#                                         disc_facility  pl_name  \
# 0                            Apache Point Observatory        2
# 1                                 Arecibo Observatory        3
# 2                              Calar Alto Observatory       29
# 3             Cerro Tololo Inter-American Observatory        5
# 4                   Fred Lawrence Whipple Observatory        6
# 6                               Haleakala Observatory        2
# 7                          Haute-Provence Observatory       69
# 9                      Kitt Peak National Observatory        1
# 10                               La Silla Observatory      303
# 11              Large Binocular Telescope Observatory        3
# 12                           Las Campanas Observatory       29
# 13                      Leoncito Astronomical Complex        1
# 14                                   Lick Observatory       36
# 15                              Mauna Kea Observatory        6
# 16                               McDonald Observatory       33
# 17                                Palomar Observatory        2
# 18                                Paranal Observatory       38
# 19                                 Parkes Observatory        2
# 20                 Roque de los Muchachos Observatory       38
# 22                                  Teide Observatory        1
# 24                                  Winer Observatory        1
# 25                    Yunnan Astronomical Observatory        3
# 26                       Acton Sky Portal Observatory        2
# 27                         Anglo-Australian Telescope       35
# 28              Atacama Large Millimeter Array (ALMA)        1
# 29         Bohyunsan Optical Astronomical Observatory       26
# 32                      European Southern Observatory        3
# 34                                             HATNet       67
# 35                                           HATSouth       73
# 36                                           HATSouth       73
# 37                                           HATSouth       73
# 38                           Infrared Survey Facility        1
# 41                                               KELT       10
# 42                                         KELT-North        7
# 43                                         KELT-South        4
# 44                                             KMTNet      121
# 47                                 Lowell Observatory        3
# 48                                     MEarth Project        2
# 49                                                MOA       33
# 52            NASA Infrared Telescope Facility (IRTF)        1
# 53              Next-Generation Transit Survey (NGTS)       22
# 54                                               OGLE      110
# 55                  Okayama Astrophysical Observatory       36
# 57                     SPECULOOS Southern Observatory        2
# 58  South African Radio Astronomy Observatory (SARAO)        1
# 59                                   Subaru Telescope       11
# 60                                          SuperWASP      122
# 61                                    SuperWASP-North        5
# 62                                    SuperWASP-South       32
# 63             Thueringer Landessternwarte Tautenburg        7
# 64                                               TrES        5
# 65                                               TrES        5
# 66                                               TrES        5
# 68                  United Kingdom Infrared Telescope        2
# 69       University of Canterbury Mt John Observatory        1
# 70                             W. M. Keck Observatory      191
# 71                                         WASP-South       11
# 73                                                 XO        6
# 74                                   Xinglong Station        2
# 75                          Zwicky Transient Facility        2
#
#                                        Name  \
# 0                  Apache Point Observatory
# 1                       Arecibo Observatory
# 2                    Calar Alto Observatory
# 3   Cerro Tololo Inter-American Observatory
# 4         Fred Lawrence Whipple Observatory
# 6                     Haleakala Observatory
# 7                Haute-Provence Observatory
# 9            Kitt Peak National Observatory
# 10                     La Silla Observatory
# 11    Large Binocular Telescope Observatory
# 12                 Las Campanas Observatory
# 13            Leoncito Astronomical Complex
# 14                         Lick Observatory
# 15                    Mauna Kea Observatory
# 16                     McDonald Observatory
# 17                      Palomar Observatory
# 18                      Paranal Observatory
# 19                       Parkes Observatory
# 20       Roque de los Muchachos Observatory
# 22                        Teide Observatory
# 24                        Winer Observatory
# 25          Yunnan Astronomical Observatory
# 26                                  Unknown
# 27                                  Unknown
# 28                                  Unknown
# 29                                  Unknown
# 32                                  Unknown
# 52  https://en.wikipedia.org/wiki/NASA_Infrared_Te...
# 53  https://en.wikipedia.org/wiki/Next-Generation_...
# 54  https://en.wikipedia.org/wiki/Optical_Gravitat...
# 55  https://en.wikipedia.org/wiki/National_Astrono...
# 57            https://en.wikipedia.org/wiki/SPECULOOS
# 58  https://en.wikipedia.org/wiki/Hartebeesthoek_R...
# 59     https://en.wikipedia.org/wiki/Subaru_Telescope
# 60  https://en.wikipedia.org/wiki/Wide_Angle_Searc...
# 61  https://en.wikipedia.org/wiki/Wide_Angle_Searc...
# 62  https://en.wikipedia.org/wiki/Wide_Angle_Searc...
# 63  https://en.wikipedia.org/wiki/Karl_Schwarzschi...
# 64  https://en.wikipedia.org/wiki/Trans-Atlantic_E...
# 65  https://en.wikipedia.org/wiki/Trans-Atlantic_E...
# 66  https://en.wikipedia.org/wiki/Trans-Atlantic_E...
# 68  https://en.wikipedia.org/wiki/United_Kingdom_I...
# 69  https://en.wikipedia.org/wiki/Mount_John_Unive...
# 70     https://en.wikipedia.org/wiki/Keck_Observatory
# 71  https://en.wikipedia.org/wiki/Wide_Angle_Searc...
# 73           https://en.wikipedia.org/wiki/XO_Project
# 74  https://en.wikipedia.org/wiki/Xinglong_Station...
# 75  https://en.wikipedia.org/wiki/Zwicky_Transient...
#
#                               Established  \
# 0                                    1985
# 1                                    1963
# 2                                    1975
# 3                                    1962
# 4                                    1968
# 6                                 Unknown
# 7                                    1937
# 9                                    1958
# 10                                   1969
# 11                                   2005
# 12                                Unknown
# 13                                   1986
# 14                                   1881
# 15                                   1967
# 16                                Unknown
# 17                                   1948
# 18                                   1999
# 19                                   1961
# 20  1979 (officially inaugurated in 1985)
# 22                                   1964
# 24                                   1983
# 25                                   1957
# 26                                Unknown
# 27                                 1974.0
# 28                                 2011.0
# 29                                 1996.0
# 32                                 1962.0
# 34                                 2001.0
# 35                                 2009.0
# 36                                 2009.0
# 37                                 2009.0
# 38                                 2000.0
# 41                                 2005.0
# 42                                 2005.0
# 43                                 2009.0
# 44                                 2015.0
# 47                                 1894.0
# 48                                 2008.0
# 49                                 2004.0
# 52                                 1977.0
# 53                                 2015.0
# 54                                 1992.0
# 55                                 1988.0
# 57                                 2017.0
# 58                                 1975.0
# 59                                 1998.0
# 60                                 2006.0
# 61                                 2006.0
# 62                                 2006.0
# 63                                 1960.0
# 64                                 2004.0
# 65                                 2004.0
# 66                                 2004.0
# 68                                 1979.0
# 69                                 1965.0
# 70                                 1993.0
# 71                                 2006.0
# 73                                 2006.0
# 74                                 1968.0
# 75                                 2018.0
#
#                                             Location  \
# 0                            Sunspot, New Mexico, US
# 1                           Arecibo, Puerto Rico, US
# 2                                     Almería, Spain
# 3                              Atacama Desert, Chile
# 4                         Mount Hopkins, Arizona, US
# 6                                   Maui, Hawaii, US
# 7                    Alpes-de-Haute-Provence, France
# 9                                Tucson, Arizona, US
# 10                             Atacama Desert, Chile
# 11                         Mount Graham, Arizona, US
# 12                                  La Serena, Chile
# 13                    Calingasta,San Juan, Argentina
# 14           Mount Hamilton,San Jose, California, US
# 15                              Mauna Kea,Hawaii, US
# 16                         Davis Mountains,Texas, US
# 17                   Palomar Mountain,California, US
# 18               Cerro Paranal,Atacama Desert, Chile
# 19                                 Parkes, Australia
# 20                   La Palma,Canary Islands, Spain.
# 48   (31.6890556, -110.884703)  earth
# 49  (-44.0045194, 170.4777273)  earth
# 52         (19.8263, -155.473)  earth
# 53    (-24.615833, -70.391111)  earth
# 54           (-29.01, -70.699)  earth
# 55     (34.576073, 133.594115)  earth
# 57    (-24.615833, -70.391111)  earth
# 58       (-25.89037, 27.68558)  earth
# 59        (19.8256, -155.4761)  earth
# 60         (28.7602, -17.8793)  earth
# 61         (28.7602, -17.8793)  earth
# 62         (-32.3783, 20.8105)  earth
# 63    (50.9281717, 11.5879359)  earth
# 64   (35.1987522, -111.651822)  earth
# 65         (33.3564, -116.865)  earth
# 66         (28.7602, -17.8793)  earth
# 68        (19.8256, -155.4761)  earth
# 69       (-43.986667, 170.465)  earth
# 70   (19.8206673, -155.468071)  earth
# 71         (-32.3783, 20.8105)  earth
# 73        (19.8256, -155.4761)  earth
# 74   (40.4659616, 117.7921122)  earth
# 75      (33.35731, -116.85981)  earth
#
#                                                  note
# 0                                             Unknown
# 1                                             Unknown
# 2                                             Unknown
# 3                                             Unknown
# 4                                             Unknown
# 6                                             Unknown
# 7                                             Unknown
# 9                                             Unknown
# 10                                            Unknown
# 11                                            Unknown
# 12                                            Unknown
# 13                                            Unknown
# 14                                            Unknown
# 15                                            Unknown
# 16                                            Unknown
# 17                                            Unknown
# 18                                            Unknown
# 19                                            Unknown
# 20                                            Unknown
# 22                                            Unknown
# 24                                            Unknown
# 25                                            Unknown
# 26                                            Unknown
# 27                                            Unknown
# 28                                            Unknown
# 29                                            Unknown
# 32                                            Unknown
# 34                                            Unknown
# 35  HATSouth has telescopes in Australia, Namibia ...
# 36  HATSouth has telescopes in Australia, Namibia ...
# 37  HATSouth has telescopes in Australia, Namibia ...
# 38                                            Unknown
# 41                                            Unknown
# 42                                            Unknown
# 43                                            Unknown
# 44                                            Unknown
# 47                                            Unknown
# 48                                            Unknown
# 49                                            Unknown
# 52                                            Unknown
# 53                                            Unknown
# 54                                            Unknown
# 55                                            Unknown
# 57                                            Unknown
# 58                                            Unknown
# 59                                            Unknown
# 60                                            Unknown
# 61                                            Unknown
# 62                                            Unknown
# 63                                            Unknown
# 64                                            Unknown
# 65  TrES has telescopes in US and Spain. The displ...
# 66  TrES has telescopes in US and Spain. The displ...
# 68                                            Unknown
# 69                                            Unknown
# 70                                            Unknown
# 71                                            Unknown
# 73                                            Unknown
# 74                                            Unknown
# 75                                            Unknown

# %%
df=df[df['type']=='earth']

# %%
df['Latitude']=df['geolocation'].apply(lambda x: (x.strip("()").split(", ")[0]))
df['Longitude']=df['geolocation'].apply(lambda x: (x.strip("()").split(", ")[1]))

# %%
df.drop('Name', axis=1).rename(columns={'disc_facility':'Name', 
                                                                                                                    'pl_name':'N discovered planets',
                                                                                                                    'Established':'Year of Establishment'})
# Out:
#                                                  Name  N discovered planets  \
# 0                            Apache Point Observatory                     2
# 1                                 Arecibo Observatory                     3
# 2                              Calar Alto Observatory                    29
# 3             Cerro Tololo Inter-American Observatory                     5
# 4                   Fred Lawrence Whipple Observatory                     6
# 6                               Haleakala Observatory                     2
# 7                          Haute-Provence Observatory                    69
# 9                      Kitt Peak National Observatory                     1
# 10                               La Silla Observatory                   303
# 11              Large Binocular Telescope Observatory                     3
# 12                           Las Campanas Observatory                    29
# 13                      Leoncito Astronomical Complex                     1
# 14                                   Lick Observatory                    36
# 15                              Mauna Kea Observatory                     6
# 16                               McDonald Observatory                    33
# 17                                Palomar Observatory                     2
# 18                                Paranal Observatory                    38
# 19                                 Parkes Observatory                     2
# 20                 Roque de los Muchachos Observatory                    38
# 22                                  Teide Observatory                     1
# 24                                  Winer Observatory                     1
# 25                    Yunnan Astronomical Observatory                     3
# 26                       Acton Sky Portal Observatory                     2
# 27                         Anglo-Australian Telescope                    35
# 28              Atacama Large Millimeter Array (ALMA)                     1
# 29         Bohyunsan Optical Astronomical Observatory                    26
# 32                      European Southern Observatory                     3
# 34                                             HATNet                    67
# 35                                           HATSouth                    73
# 36                                           HATSouth                    73
# 37                                           HATSouth                    73
# 38                           Infrared Survey Facility                     1
# 41                                               KELT                    10
# 42                                         KELT-North                     7
# 43                                         KELT-South                     4
# 44                                             KMTNet                   121
# 47                                 Lowell Observatory                     3
# 48                                     MEarth Project                     2
# 49                                                MOA                    33
# 52            NASA Infrared Telescope Facility (IRTF)                     1
# 53              Next-Generation Transit Survey (NGTS)                    22
# 54                                               OGLE                   110
# 55                  Okayama Astrophysical Observatory                    36
# 57                     SPECULOOS Southern Observatory                     2
# 58  South African Radio Astronomy Observatory (SARAO)                     1
# 59                                   Subaru Telescope                    11
# 60                                          SuperWASP                   122
# 61                                    SuperWASP-North                     5
# 62                                    SuperWASP-South                    32
# 63             Thueringer Landessternwarte Tautenburg                     7
# 64                                               TrES                     5
# 65                                               TrES                     5
# 66                                               TrES                     5
# 68                  United Kingdom Infrared Telescope                     2
# 69       University of Canterbury Mt John Observatory                     1
# 70                             W. M. Keck Observatory                   191
# 71                                         WASP-South                    11
# 73                                                 XO                     6
# 74                                   Xinglong Station                     2
# 75                          Zwicky Transient Facility                     2
#
#                                                  Link  \
# 0   https://en.wikipedia.org/wiki/Apache_Point_Obs...
# 1   https://en.wikipedia.org/wiki/Arecibo_Observatory
# 2   https://en.wikipedia.org/wiki/Calar_Alto_Obser...
# 3   https://en.wikipedia.org/wiki/Cerro_Tololo_Int...
# 4   https://en.wikipedia.org/wiki/Fred_Lawrence_Wh...
# 6   https://en.wikipedia.org/wiki/Haleakala_Observ...
# 7   https://en.wikipedia.org/wiki/Haute-Provence_O...
# 9   https://en.wikipedia.org/wiki/Kitt_Peak_Nation...
# 10  https://en.wikipedia.org/wiki/La_Silla_Observa...
# 11  https://en.wikipedia.org/wiki/Large_Binocular_...
# 12  https://en.wikipedia.org/wiki/Las_Campanas_Obs...
# 13  https://en.wikipedia.org/wiki/Leoncito_Astrono...
# 14     https://en.wikipedia.org/wiki/Lick_Observatory
# 15  https://en.wikipedia.org/wiki/Mauna_Kea_Observ...
# 16  https://en.wikipedia.org/wiki/McDonald_Observa...
# 17  https://en.wikipedia.org/wiki/Palomar_Observatory
# 18  https://en.wikipedia.org/wiki/Paranal_Observatory
# 41                                 2005.0
# 42                                 2005.0
# 43                                 2009.0
# 44                                 2015.0
# 47                                 1894.0
# 48                                 2008.0
# 49                                 2004.0
# 52                                 1977.0
# 53                                 2015.0
# 54                                 1992.0
# 55                                 1988.0
# 57                                 2017.0
# 58                                 1975.0
# 59                                 1998.0
# 60                                 2006.0
# 61                                 2006.0
# 62                                 2006.0
# 63                                 1960.0
# 64                                 2004.0
# 65                                 2004.0
# 66                                 2004.0
# 68                                 1979.0
# 69                                 1965.0
# 70                                 1993.0
# 71                                 2006.0
# 73                                 2006.0
# 74                                 1968.0
# 75                                 2018.0
#
#                                             Location  \
# 0                            Sunspot, New Mexico, US
# 1                           Arecibo, Puerto Rico, US
# 2                                     Almería, Spain
# 3                              Atacama Desert, Chile
# 4                         Mount Hopkins, Arizona, US
# 6                                   Maui, Hawaii, US
# 7                    Alpes-de-Haute-Provence, France
# 9                                Tucson, Arizona, US
# 10                             Atacama Desert, Chile
# 11                         Mount Graham, Arizona, US
# 12                                  La Serena, Chile
# 13                    Calingasta,San Juan, Argentina
# 14           Mount Hamilton,San Jose, California, US
# 15                              Mauna Kea,Hawaii, US
# 16                         Davis Mountains,Texas, US
# 17                   Palomar Mountain,California, US
# 18               Cerro Paranal,Atacama Desert, Chile
# 19                                 Parkes, Australia
# 20                   La Palma,Canary Islands, Spain.
# 22                    Tenerife,Canary Islands, Spain
# 24                              Sonoita, Arizona, US
# 25                             Kunming,Yunnan, China
# 26                                    Acton, MA, USA
# 27                              New South Wales, AUS
# 28                         Antofagasta Region, Chile
# 29                            Youngchun, South Korea
# 32                             Atacama Desert, Chile
# 34                                 Budapest, Hungary
# 35                                         Australia
# 36                                           Namibia
# 37                                             Chile
# 38           Sutherland, Northern Cape, South Africa
# 41                                       Arizona, US
# 42                                       Arizona, US
# 43           Sutherland, Northern Cape, South Africa
# 44                 Mt. Cerro Tololo, Coquimbo, Chile
# 47                            Flagstaff, Arizona, US
# 48                        Mount Hopkins, Arizona, US
# 49             Lake Tekapo,South Island, New Zealand
# 52                            Hawaiʻi County, Hawaii
# 53                                    Atacama, Chile
# 54                   Las Campanas Observatory, Chile
# 55                                 Asakuchi, Okayama
# 57                                    Atacama, Chile
# 58                  Gauteng, Transvaal, South Africa
# 59                                        Hawaii, US
# 60                   La Palma, Canary Islands, Spain
# 61                   La Palma, Canary Islands, Spain
# 62           Sutherland, Northern Cape, South Africa
# 63                                     Jena, Germany
# 64                            Flagstaff, Arizona, US
# 65   Palomar Mountains, San Diego County, California
# 66                Mount Teide, Canary Islands, Spain
# 68                                        Hawaii, US
# 69        Mackenzie Basin, South Island, New Zealand
# 70                              Mauna Kea,Hawaii, US
# 71           Sutherland, Northern Cape, South Africa
# 73                                        Hawaii, US
# 74  Xinglong County,Chengde,Hebeiprovince, China[12]
# 75                  San Diego County, California, US
#
#                    geolocation   type  \
# 0     (32.7892103, -105.81857)  earth
# 1    (18.4047499, -66.6810353)  earth
# 2     (36.8414197, -2.4628135)  earth
# 3   (-24.5563029, -69.4226479)  earth
# 4    (31.6890556, -110.884703)  earth
# 28                                                NaN     -23.0193
# 29                                                NaN    43.740158
# 32                                                NaN  -24.5563029
# 34                                                NaN      47.4997
# 35  HATSouth has telescopes in Australia, Namibia ...          -25
# 36  HATSouth has telescopes in Australia, Namibia ...          -22
# 37  HATSouth has telescopes in Australia, Namibia ...          -34
# 38                                                NaN     -32.3783
# 41                                                NaN        34.29
# 42                                                NaN    31.665578
# 43                                                NaN     -32.3783
# 44                                                NaN   -30.169167
# 47                                                NaN   35.1987522
# 48                                                NaN   31.6890556
# 49                                                NaN  -44.0045194
# 52                                                NaN      19.8263
# 53                                                NaN   -24.615833
# 54                                                NaN       -29.01
# 55                                                NaN    34.576073
# 57                                                NaN   -24.615833
# 58                                                NaN    -25.89037
# 59                                                NaN      19.8256
# 60                                                NaN      28.7602
# 61                                                NaN      28.7602
# 62                                                NaN     -32.3783
# 63                                                NaN   50.9281717
# 64                                                NaN   35.1987522
# 65  TrES has telescopes in US and Spain. The displ...      33.3564
# 66  TrES has telescopes in US and Spain. The displ...      28.7602
# 68                                                NaN      19.8256
# 69                                                NaN   -43.986667
# 70                                                NaN   19.8206673
# 71                                                NaN     -32.3783
# 73                                                NaN      19.8256
# 74                                                NaN   40.4659616
# 75                                                NaN     33.35731
#
#        Longitude
# 0     -105.81857
# 1    -66.6810353
# 2     -2.4628135
# 3    -69.4226479
# 4    -110.884703
# 6   -156.3106833
# 7      6.1878515
# 9    -110.974847
# 10   -69.4226479
# 11  -109.8713876
# 12   -71.2519545
# 13   -69.8827275
# 14  -121.8626646
# 15   -155.468071
# 16  -103.9293648
# 17  -116.8786359
# 18   -70.4045723
# 19   147.9761363
# 20   -17.8572686
# 22   -16.6214471
# 24  -110.6619555
# 25   102.7086139
# 26    -71.433333
# 27       149.067
# 28      -67.7532
# 29   125.3005774
# 32   -69.4226479
# 34      18.96389
# 35           133
# 36            17
# 37           -71
# 38       20.8105
# 41       -111.66
# 42   -110.601783
# 43       20.8105
# 44    -70.806389
# 47   -111.651822
# 48   -110.884703
# 49   170.4777273
# 52      -155.473
# 53    -70.391111
# 54       -70.699
# 55    133.594115
# 57    -70.391111
# 58      27.68558
# 59     -155.4761
# 60      -17.8793
# 61      -17.8793
# 62       20.8105
# 63    11.5879359
# 64   -111.651822
# 65      -116.865
# 66      -17.8793
# 68     -155.4761
# 69       170.465
# 70   -155.468071
# 71       20.8105
# 73     -155.4761
# 74   117.7921122
# 75    -116.85981

# %%
import pandas as pd
all_observatories=pd.read_csv('../data/observatories_exoplanets_geolocated.csv').drop('Name', axis=1).rename(columns={'disc_facility':'Name', 
                                                                                                                    'pl_name':'N of discovered planets',
                                                                                                                    'Established':'Year of Establishment'})
all_observatories.fillna('Unknown', inplace=True)
all_observatories['note']=all_observatories['note'].replace('Unknown', '')

obs_space=all_observatories[all_observatories['type']=='space'].copy()
obs_space['Year of Establishment']=[x.split('.')[0] for x in obs_space['Year of Establishment']]
obs_space=obs_space.sort_values(by='N of discovered planets', ascending=False)
obs_space['Name']='🚀 ' + obs_space['Name']

# %%
len(obs_space)
# Out:
# 10
